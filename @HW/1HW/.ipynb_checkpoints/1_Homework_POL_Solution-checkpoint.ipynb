# %% [markdown]
# Политология, 4 курс, 1 модуль
#
# # Анализ данных в Python
#
# # Домашняя работа 1
#
# *Авторы: Татьяна Рогович*

# %% [markdown]
# #### Задание 1. Проблемы с памятью (0.5 балла)
#
# Вы постоянно забываете последнюю цифру от пин-кода своей карты. По этой причине вы написали себе напоминалку в телефоне, где сказано: "Последняя цифра пин-кода - это предпоследнияя цифра года рождения моего любимого актера" (ведь это, очевидно, вы никогда не забудете!). На вход программе подается четырехзначное число. На выходе вы должны получить одно число от 0 до 9 - последнюю цифру своего пин-кода.
#
# *Примечание: Задачу необходимо решить именно методами арифметики, а не методами строк!*
#
# **Тест 1**
# **Пример ввода:**
# 1966
#
# **Вывод:**
# 6
#
# **Тест 2**
# **Пример ввода:**
# 1882
#
# **Вывод:**
# 8

# %%
# ваш код здесь
# ваш код здесь
x = int(input())
print(x // 10 % 10)
# Out:
# 9

# %% [markdown]
# #### Задание 2. Вова путешествует (1 балл)
#
# Вова очень любит путешествовать. Ради удобства в своих путешествиях по миру, он решил написать программу, которая могла бы перевести имя человека в формат, подходящий для этой страны (см. пример).
#
# Пока что Вова хочет сделать эту программу работающей для двух стран. Это Япония и Германия. Программа принимает на ввод фамилию, пол и страну, в которую человек едет. Выводит приветствие с корректным для этой страны обращением по формату в примере.
#
# Для Германии - "герр" (для мужчин) и "фрау" (для женщин).
#
# Для Японии вне зависимости от пола - постфикс "-сан".
#
# Обратите внимание, что название страны в выводе меняет окончание (но в обоих случаях, это "я" -> "ю")
#
# **Тест 1**
# **Пример ввода**
# Соколов
# М
# Япония
#
# **Вывод**
# Если вы едете в Японию, вас будут называть Соколов-сан.
#
# **Тест 2**
# **Пример ввода**
# Иванова
# Ж
# Германия
#
# **Вывод**
# Если вы едете в Германию, вас будут называть фрау Иванова.

# %%
# ваше решение здесь
# ваше решение здесь
name = input()
gender = input()
country = input()

if country == 'Япония':
    print(f'Если вы едете в {country[:-1]+"ю"}, вас будут называть {name}-сан.')
else:
    if gender == 'М':
        print(f'Если вы едете в {country[:-1]+"ю"}, вас будут называть герр {name}.')
    else:
        print(f'Если вы едете в {country[:-1]+"ю"}, вас будут называть фрау {name}.')
# Out:
# Если вы едете в Японию, вас будут называть Иванов-сан.

# %% [markdown]
# #### Задание 3. Угадайка (1.5 балл)
#
# Ваша задача - воплотить игру "Угадай число".
#
# Программа должна генерировать случайное число от 1 до 10 (этот код мы уже написали, просто запустите его). Число генерируется в формате int.
#
# На ввод программа принимает догадки пользователя в интервале от 1 до 10 и сравниваниет догадку со значением переменной number, которая генерируется в ячейке, которую вы запустите и выводит результат сравнения ("Вы угадали!" или "Попробуйте еще раз!). Мы предполагаем, что пользователь всегда вводит число в нужном интервале.
#
# Программа должна работать до тех пор, пока число не будет угадано, или пока не закончатся попытки. Когда пользователь угадывает число, программа сообщает об этом и перестает работать.
#
# Всего у пользователя 3 попытки угадать число, после 3 неправильных попыток программа сообщает об этом и прекращает работать.

# %%
# запустите это ячейку, чтобы сгенерировать случаное число
import random   # импортируем модуль random и используем функцию randint(), 
number = random.randint(1, 10) # которая генерирует случайное число от 1 до 10
print(number) # проверка того, какое число загадалось, чтобы вам было удобнее отлаживать программу
# Out:
# 3

# %%
n = 3
while n != 0:
    guess = int(input())
    if guess == number:
        print('Вы угадали!')
        break
    else:
        print('Попробуйте еще раз!')
        n -= 1
else:
    print('Вы проиграли') # по условию не просили такой вывод, но здорово, если он есть
# Out:
# Попробуйте еще раз!
# Попробуйте еще раз!
# Попробуйте еще раз!
# Вы проиграли

# %% [markdown]
# ### Задание 4. Оценки (3 балла)
#
# *1 балл*
# **Пункт 1**
# Вам дан словарь с именами студентов и их оценками за разные предметы по десятибаллной шкале. Напишите программу, которая бы считала среднюю оценку за предмет и округляла ее до целого числа(используйте функцию round()). Чтобы найти среднюю оценку нужно сложить оценки всех студентов за предмет и разделить сумму на количество студентов. Найти сумму элементов списка, можно функцией sum(). Так, первый предмет - это нулевой элемент списка оценок каждого студента и так далее.
#
# Программа должна приниматься на ввод номер предмет (от 1 до 8, обратите внимание, что не от 0 до 7), а выводить округленную среднюю оценку за этот предмет.
#
# **Пример ввода:**
#
# 1
#
# **Пример вывода:**
#
# Предмет 1 - 4

# %%
marks = {'Mary' : [5, 8, 9, 10, 3, 5, 6, 6],
         'John' : [3, 3, 6, 8, 2, 1, 8, 5],
         'Alex' : [4, 4, 7, 4, 7, 3, 2, 9],
         'Patricia' : [2, 1, 6, 8, 2, 3, 7, 4]}

categories = {'отлично' : [8, 9, 10],
              'хорошо' : [6, 7],
              'удовлетворительно' : [4, 5],
              'неуд' : [0, 1, 2, 3]}

course = int(input('Введите номер курса от 1 до 8: ')) - 1

av = []
for student in marks:
    av.append(marks[student][course])
    
print(f'Курс {course + 1} - {round(sum(av)/len(av))}')
# Out:
# Курс 1 - 4

# %% [markdown]
# *1 балл*
# **Пункт 2**
# Напишите программу, которая бы сопостовляла оценку, найденную в предыдущем пункте, со вторым словарем, где оценкам в числах соответсвуют категории "хорошо", "отлично" и так далее. Программа принимает на ввод номер предмета (от 1 до 8, обратите внимание, что не от 0 до 7), подсчитывает среднюю оценку за этот курс, а выводит буквенное значение оценки от "неуд" до "отлично" из словаря categories
#
# **Пример ввода**
#
# 1
#
# **Пример вывода:**
#
# Предмет 1 - удовлетворительно

# %%
marks = {'Mary' : [5, 8, 9, 10, 3, 5, 6, 6],
         'John' : [3, 3, 6, 8, 2, 1, 8, 5],
         'Alex' : [4, 4, 7, 4, 7, 3, 2, 9],
         'Patricia' : [2, 1, 6, 8, 2, 3, 7, 4]}

categories = {'отлично' : [8, 9, 10],
              'хорошо' : [6, 7],
              'удовлетворительно' : [4, 5],
              'неуд' : [0, 1, 2, 3]}

course = int(input('Введите номер курса от 1 до 8: ')) - 1

av = []
for student in marks:
    av.append(marks[student][course])
    
print(f'Курс {course + 1} - {round(sum(av)/len(av))}')
mark_av = round(sum(av)/len(av))

for key in categories:
    if mark_av in categories[key]:
        print(f'Курс {course + 1} - {key}')
# Out:
# Курс 1 - 4
# Курс 1 - удовлетворительно

# %% [markdown]
# *1 балл*
# **Пункт 3**
# Напишите программу, которая бы принимала на ввод буквенное значение оценки "отлично", "хорошо", "удовлетворительно" или "неуд", смотрела бы в словаре categories, какие оценки соответствуют этой категории и выводила бы количество оценок из этой категории в словаре marks.
#
#
# **Пример ввода:**
# отлично
#
# **Пример вывода:**
# 7

# %%
marks = {'Mary' : [5, 8, 9, 10, 3, 5, 6, 6],
         'John' : [3, 3, 6, 8, 2, 1, 8, 5],
         'Alex' : [4, 4, 7, 4, 7, 3, 2, 9],
         'Patricia' : [2, 1, 6, 8, 2, 3, 7, 4]}

categories = {'отлично' : [8, 9, 10],
              'хорошо' : [6, 7],
              'удовлетворительно' : [4, 5],
              'неуд' : [0, 1, 2, 3]}
# ваше решение здесь

mark_cat = input()
total = 0
for mark in categories[mark_cat]:
    for student in marks.values():
        total += student.count(mark)
        
print(total)
# Out:
# 7

# %% [markdown]
# #### Задание 5. Магнолия (2 балла)
#
# В магазине "Магнолия" проходит акция - даются скидки на товары, название которых начинается на заданную букву.
#
# У Маши есть список покупок, состоящий из строк вида "цена, название, количество". Помогите ей посчитать, сколько денег она сэкономит (общую сумму скидки).
#
# Количество записей в Машином списке покупок может быть любым. Каждая запись вводится с новой строки. Записи вводятся до тех пор, пока пользователь не введет "Конец списка". После этого одной строкой вводится буква, по которой сегодня определяется скидка. Если название продукта начинается на заданную букву, то на этот продукт действует скидка 15 процентов.
#
# Образец вывода смотрите в примере. Если ни на один товар скидка не действует, то программа должна вывести "Скидка: 0 рублей"
#
# *Вы считали категории в список списков, где каждая строка выглядит как в образце  - 1 балл*
# `[цена (int), название (str), количество (int)]`
# Например, `[120, 'мандарины (1 кг)', 2]`
#
# *Подсчет скидки - 1 балл.*
#
# **Пример ввода**
# 120 руб., мандарины (1 кг), 2 кг.
# 70 руб., молоко, 3 пакета
# 15 руб., батон сдобный, 1 штука
# 345 руб., белое вино, 1 бутылка
# 120 руб., моцарелла, 2 упаковки
# Конец списка
# м
#
# **Вывод**
#
# Cкидка: 103.5 руб.

# %%
# ваше решение здесь
item = input()
shopping_list = []

while item != 'Конец списка':
    temp = []
    temp.append(int(item.split(', ')[0].split()[0]))
    temp.append(item.split(', ')[1])
    temp.append(item.split(', ')[2].split()[0])
    shopping_list.append(temp)
    item = input()
    
letter = input()
print(shopping_list, letter)
# Out:
# [[120, 'мандарины (1 кг)', '2'], [70, 'молоко', '3'], [15, 'батон сдобный', '1'], [345, 'белое вино', '1'], [120, 'моцарелла', '2']] м

# %%
discount = 0
for item in shopping_list:
    if item[1].startswith(letter):
        discount += item[0]*int(item[2])*0.15
        
print(f'Скидка: {discount} руб.')
# Out:
# Скидка: 103.5 руб.

# %% [markdown]
# # Задание 7: буквы, строки и слова (2 балла)
#
# Дан файл. Определите сколько в нем букв (латинского алфавита), слов, строк. Выведите три найденных числа в формате, приведенном в примере. Словом считается последовательность больших и маленьких латинских букв. Все остальные символы считаются разделителями слов. Если будете решать регулярками, то будьте аккуратны, потому что некоторые выражения "захватывают" кроме букв лишние символы. Если будете пользоваться методами строк, то .isalpha() проверяет на то, что строка является буквой.
#
# Пример входного файла:
# ```
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# ```
# Пример ответа:
#
# ```
# Input file contains:
# 108 letters
# 20 words
# 4 lines
# ```
#
# **Входной файл: problem.txt**
# **Ответ нужно вывести в блокноте по образцу в примере**
#
# В количестве букв первая цифра 4, а последняя 3.
# В количестве слов: 1 и 6.
# В количестве строк: 1 и 0.

# %%
import re
with open('problem.txt') as fh:
    letters = 0
    words = 0
    lines = fh.readlines()
    for line in lines:
        letters += len(re.findall(r'[a-zA-Z]', line.strip()))
        words += len(re.findall(r'[a-zA-Z]+', line.strip()))

print('Input file contains:')
print(letters, 'letters')
print(words, 'words')
print(len(lines), 'lines')
# Out:
# Input file contains:
# 44473 letters
# 11496 words
# 1000 lines

# %%
with open('problem.txt') as fh:
    letters = 0
    words = 0
    lines = fh.readlines()
    for line in lines:
        for symbol in line:
            if symbol.isalpha():
                letters += 1
                previous_letter = True
            elif previous_letter:
                words += 1
                previous_letter = False
                
print('Input file contains:')
print(letters, 'letters')
print(words, 'words')
print(len(lines), 'lines')
# Out:
# Input file contains:
# 44473 letters
# 11496 words
# 1000 lines
